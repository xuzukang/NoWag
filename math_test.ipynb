# %%
import numpy as np

# %%
n_in = 100
n_out = 200
k = 5

np.random.seed(0)

for i in range(1000):
    
    n_in = np.random.randint(10,1000)
    n_out = np.random.randint(10,1000)
    k = np.random.randint(5,min(n_in,n_out))
    
    A = np.random.randn(n_out, k)
    B = np.random.randn(k, n_in)

    H = np.random.randn(n_in,n_in)
    H = H + H.T


    x1 = np.trace(A @ B @ H @ B.T @ A.T)

    B_vector = B.reshape(-1,1)

    x2 = (B_vector.T @ (np.kron(A.T @ A, H) @ B_vector))[0,0]

    if not np.isclose(x1, x2):
        print(x1,x2)
        print(n_in,n_out,k)
        break

print("done")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[15], line 24
#      20 x1 = np.trace(A @ B @ H @ B.T @ A.T)
#      22 B_vector = B.reshape(-1,1)
# ---> 24 x2 = (B_vector.T @ (np.kron(A.T @ A, H) @ B_vector))[0,0]
#      26 if not np.isclose(x1, x2):
#      27     print(x1,x2)
#
# File <__array_function__ internals>:200, in kron(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/lib/shape_base.py:1179, in kron(a, b)
#    1177 b_arr = expand_dims(b_arr, axis=tuple(range(0, nd*2, 2)))
#    1178 # In case of `mat`, convert result to `array`
# -> 1179 result = _nx.multiply(a_arr, b_arr, subok=(not is_any_mat))
#    1181 # Reshape back
#    1182 result = result.reshape(_nx.multiply(as_, bs))
#
# MemoryError: Unable to allocate 1.56 TiB for an array with shape (482, 961, 482, 961) and data type float64

# %%
import torch
import torch.nn as nn


A = torch.ones(1)
A_optimize = torch.optim.Adam([A], lr=1)

# %%
losses = []
x = []
for i in range(100):
    loss = A**2
    # print(loss)
    losses.append(loss.item())
    x.append(A.item())
    A.grad = 2*A
    A_optimize.step()
    A_optimize.zero_grad()

# %%
import matplotlib.pyplot as plt
plt.plot(x,losses)

# %%
def f(**kwargs):
    print(kwargs)
    kwargs["test"] = 1
    print(kwargs)

f(a=1,b=2,test = 3)
# Out:
# {'a': 1, 'b': 2, 'test': 3}
